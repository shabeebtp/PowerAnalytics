# %% [markdown]
# ### Importing the required libraries

# %%
import pandas as pd                        # to import the pandas library

import warnings                            # to ignore warning message
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Exploring The Dataset

# %%
# Importing and exploring the dataset

data=pd.read_csv('churn-bigml-80.csv')
data                # it shows top5 and Bottom5 rows
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 2661    SC              79        415                 No              No
# 2662    AZ             192        415                 No             Yes
# 2663    WV              68        415                 No              No
# 2664    RI              28        510                 No              No
# 2665    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %% [markdown]
# ### head()

# %%
data.head()        # To show top5 records of the dataset
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %% [markdown]
# ### tail()

# %%
data.tail()           # To show last5 records of the dataset
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 2661    SC              79        415                 No              No
# 2662    AZ             192        415                 No             Yes
# 2663    WV              68        415                 No              No
# 2664    RI              28        510                 No              No
# 2665    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 2661                      0              134.7               98
# 2662                     36              156.2               77
# 2663                      0              231.1               57
# 2664                      0              180.8              109
# 2665                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %% [markdown]
# ### info()

# %%
data.info()   # it show the basic information about the dataset
# It shows indexes,columns counts,each column name with its non-null values count & data-type,and memory of DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2666 entries, 0 to 2665
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   2666 non-null   object
#  1   Account length          2666 non-null   int64
#  2   Area code               2666 non-null   int64
#  3   International plan      2666 non-null   object
#  4   Voice mail plan         2666 non-null   object
#  5   Number vmail messages   2666 non-null   int64
#  6   Total day minutes       2666 non-null   float64
#  7   Total day calls         2666 non-null   int64
#  8   Total day charge        2666 non-null   float64
#  9   Total eve minutes       2666 non-null   float64
#  10  Total eve calls         2666 non-null   int64
#  11  Total eve charge        2666 non-null   float64
#  12  Total night minutes     2666 non-null   float64
#  13  Total night calls       2666 non-null   int64
# ...

# %% [markdown]
# ### shape

# %%
data.shape                  # To show the number of Rows & Columns in the DataFrame
# Out:
# (2666, 20)

# %% [markdown]
# ### nunique()

# %%
data.nunique()              # To show the number of unique values in each column
# Out:
# State                       51
# Account length             205
# Area code                    3
# International plan           2
# Voice mail plan              2
# Number vmail messages       42
# Total day minutes         1489
# Total day calls            115
# Total day charge          1489
# Total eve minutes         1442
# Total eve calls            120
# Total eve charge          1301
# Total night minutes       1444
# Total night calls          118
# Total night charge         885
# Total intl minutes         158
# Total intl calls            21
# Total intl charge          158
# Customer service calls      10
# Churn                        2
# dtype: int64

# %% [markdown]
# ### columns

# %%
data.columns              # To show all the column names of the DataFrame
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
data.dtypes                # To show the data-type of each column
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Churn                        bool
# dtype: object

# %% [markdown]
# ### describe()

# %%
data.describe()

# It gives the summary statistics of all numeric columns, it checks extreme outliers and Large deviations etc.
# It shows the count of non-null values in each column, and mean, std,minimum, maximum,
# 25th, 50th, 75th percentile value of each column
# Percentile means - how many of the values are less than the given percentile
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     2666.000000  2666.000000            2666.000000         2666.00000
# mean       100.620405   437.438860               8.021755          179.48162
# std         39.563974    42.521018              13.612277           54.21035
# min          1.000000   408.000000               0.000000            0.00000
# 25%         73.000000   408.000000               0.000000          143.40000
# 50%        100.000000   415.000000               0.000000          179.95000
# 75%        127.000000   510.000000              19.000000          215.90000
# max        243.000000   510.000000              50.000000          350.80000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      2666.000000       2666.000000        2666.000000      2666.000000
# mean        100.310203         30.512404         200.386159       100.023631
# ...

# %% [markdown]
# ## Checking Missing and Duplicate Values

# %%
data.isna().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
data[data.duplicated()]            # To show the duplicate records present in the Dataframe
# Out:
# Empty DataFrame
# Columns: [State, Account length, Area code, International plan, Voice mail plan, Number vmail messages, Total day minutes, Total day calls, Total day charge, Total eve minutes, Total eve calls, Total eve charge, Total night minutes, Total night calls, Total night charge, Total intl minutes, Total intl calls, Total intl charge, Customer service calls, Churn]
# Index: []

# %%
# in this dataframe there is no duplicate values present

# data=data.drop_duplicates()      # To drop all the duplicate records from the DataFrame,and saving the updated dataframe

# %% [markdown]
# # Analyzing the 'Churn' variable

# %% [markdown]
# ### unique()

# %%
data['Churn'].unique()          # to show the unique values present in the column 'Churn'
# Out:
# array([False,  True])

# %% [markdown]
# ### value_counts()

# %%
data['Churn'].value_counts()   # to show the count of the unique values of the column 'Churn'
# Out:
# Churn
# False    2278
# True      388
# Name: count, dtype: int64

# %% [markdown]
# # Length Of Data

# %%
len(data)
# Out:
# 2666

# %% [markdown]
# ### Pie Chart

# %%
slices=[2278,388]
labels=["Churned","Not Churned"]
colors=['blue','black']
plt.title('Churned vs Non-Churned Customers')
explodes=[0,0.2]
plt.text
plt.pie(slices,labels=labels,colors=colors,autopct='%1.3f%%',startangle=50,wedgeprops={'linewidth':4,'edgecolor':'w'},explode=explodes,shadow=True,textprops={'color':'white'})
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier as knc
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC

import seaborn as sns

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score,confusion_matrix

import warnings 
warnings.filterwarnings('ignore')

# %%
data.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
data=data.drop(['State','Area code','Number vmail messages'],axis=1)

# %%
le1=LabelEncoder()
le2=LabelEncoder()

# %%
data['International plan']=le1.fit_transform(data['International plan'])
data['Voice mail plan']=le1.fit_transform(data['Voice mail plan'])
data
# Out:
#       Account length  International plan  Voice mail plan  Total day minutes  \
# 0                128                   0                1              265.1
# 1                107                   0                1              161.6
# 2                137                   0                0              243.4
# 3                 84                   1                0              299.4
# 4                 75                   1                0              166.7
# ...              ...                 ...              ...                ...
# 2661              79                   0                0              134.7
# 2662             192                   0                1              156.2
# 2663              68                   0                0              231.1
# 2664              28                   0                0              180.8
# 2665              74                   0                1              234.4
#
# ...

# %%
x=data.drop('Churn',axis=1)
y=data['Churn']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=56)

# %%
len(x_test)
# Out:
# 667

# %%
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.fit_transform(x_test)

# %%
model=RandomForestClassifier()
model.fit(x_train,y_train)

print(model.score(x_test,y_test))
print(model.score(x_train,y_train))
# Out:
# 0.9490254872563718
# 1.0

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#        False, False, False,  True, False, False, False, False, False,
#        False, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True, False,
#        False, False,  True,  True, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9490254872563718

# %%
cm=confusion_matrix(y_pred,y_test)
cm
# Out:
# array([[549,  26],
#        [  8,  84]], dtype=int64)

# %%
plt.figure(figsize=(6,6)) #facecolor='black')
sns.heatmap(cm,annot=True,cmap='Greys')
plt.xlabel('Prediction')
plt.ylabel('Targets')
# Out:
# Text(45.722222222222214, 0.5, 'Targets')

# %%
model.predict([[104,1,1,200,110,40,190,200,10,250,91,10,10,4,3,0]])

# %%
Account_length=int(input("Account length  : "))

International_plan=input("International plan yes/no : ")
International_plan=le2.fit_transform([International_plan])

Voice_mail_plan=input("Voice mail plan yes/no : ")
Voice_mail_plan=le2.fit_transform([Voice_mail_plan])

Total_day_minutes=int(input("Total day minutes  : "))
Total_day_calls=int(input("Total day calls  : "))
Total_day_charge=int(input("Total day charge  : "))
Total_eve_minutes=int(input("Total eve minutes  : "))
Total_eve_calls=int(input("Total eve calls  : "))
Total_eve_charge=int(input("Total eve charge  : "))
Total_night_minutes=int(input("Total night minutes  : "))
Total_night_calls=int(input("Total night calls  : "))
Total_night_charge=int(input("Total night charge  : "))
Total_intl_minutes=int(input("Total intl minutes  : "))
Total_intl_calls=int(input("Total intl calls  : "))
Total_intl_charge=int(input("Total intl charge  : "))
Customer_service_calls=int(input("Customer service calls  : "))


model.predict([[Account_length,International_plan[0],Voice_mail_plan[0],Total_day_minutes,Total_day_calls,Total_day_charge,Total_eve_minutes,Total_eve_calls,Total_eve_charge,Total_night_minutes,Total_night_calls,Total_night_charge,Total_intl_minutes,Total_intl_calls,Total_intl_charge,Customer_service_calls]])
# Out:
# Account length  : 5
# International plan yes/no : no
# Voice mail plan yes/no : yes
# Total day minutes  : 20
# Total day calls  : 5
# Total day charge  : 100
# Total eve minutes  : 5
# Total eve calls  : 1
# Total eve charge  : 10
# Total night minutes  : 120
# Total night calls  : 1
# Total night charge  : 1000
# Total intl minutes  : 0
# Total intl calls  : 0
# Total intl charge  : 0
# Customer service calls  : 15
# array([ True])

# %%
model1=XGBClassifier()
model1.fit(x_train,y_train)

print(model1.score(x_test,y_test))
print(model1.score(x_train,y_train))
# Out:
# 0.9475262368815592
# 1.0

# %%
# model3=knc()
# model3.fit(x_train,y_train)

# print(model3.score(x_test,y_test))
# print(model3.score(x_train,y_train))

# %%
model4=GradientBoostingClassifier()
model4.fit(x_train,y_train)

print(model4.score(x_test,y_test))
print(model4.score(x_train,y_train))
# Out:
# 0.9505247376311844
# 0.9739869934967483

# %%
model5=DecisionTreeClassifier()
model5.fit(x_train,y_train)

print(model5.score(x_test,y_test))
print(model5.score(x_train,y_train))
# Out:
# 0.9280359820089955
# 1.0

# %%
model6=AdaBoostClassifier()
model6.fit(x_train,y_train)

print(model6.score(x_test,y_test))
print(model6.score(x_train,y_train))
# Out:
# 0.863568215892054
# 0.8999499749874937

# %%
model7=LogisticRegression()
model7.fit(x_train,y_train)

print(model7.score(x_test,y_test))
print(model7.score(x_train,y_train))
# Out:
# 0.8350824587706147
# 0.8569284642321161

# %%
model8=GaussianNB()
model8.fit(x_train,y_train)

print(model8.score(x_test,y_test))
print(model8.score(x_train,y_train))
# Out:
# 0.8515742128935532
# 0.8609304652326163

# %% [markdown]
# #  SVC

# %%
# linear=SVC(kernel='linear',C=1500)
# linear.fit(x_train,y_train)
# print(linear.score(x_test,y_test))
# print(linear.score(x_train,y_train))
# Out:
# 0.8425787106446777
# 0.8724362181090545

# %%
# rbf=SVC()
# rbf.fit(x_train,y_train)
# print(rbf.score(x_test,y_test))
# print(rbf.score(x_train,y_train))
# Out:
# 0.8350824587706147
# 0.8609304652326163

# %%
# sigmoid=SVC(kernel='sigmoid',C=500)
# sigmoid.fit(x_train,y_train)
# print(sigmoid.score(x_test,y_test))
# print(sigmoid.score(x_train,y_train))
# Out:
# 0.7406296851574213
# 0.7538769384692346

# %%
poly=SVC(kernel='poly',degree=3,gamma=15,C=500)
poly.fit(x_train,y_train)
print(poly.score(x_test,y_test))
print(poly.score(x_train,y_train))

# %% [markdown]
# # Hyper Tuning

# %%
model_params = {
    "random_forest": {"model": RandomForestClassifier(), "params": {"n_estimators": [10, 200, 100], "random_state": [42, 100, 500]}},
    "linear_regression": {"model": LogisticRegression(), "params": {"fit_intercept": [True, False]}},
    "adaboost": {"model": AdaBoostClassifier(base_estimator=DecisionTreeClassifier()), "params": {"n_estimators": [50, 100, 200], "learning_rate": [0.01, 0.1, 0.2]}},
    "gradient_boosting": {"model": GradientBoostingClassifier(), "params": {"n_estimators": [50, 100, 200], "learning_rate": [0.1, 0.15, 0.2, 0.3], "max_depth": [4, 5, 6, 7]}},
    "xgboost": {"model": XGBClassifier(), "params": {"n_estimators": [60, 100, 200], "learning_rate": [0.1, 0.15, 0.2, 0.25], "max_depth": [4, 5, 6, 7]}},
    "decision_tree": {"model": DecisionTreeClassifier(), "params": {"max_depth": [5, 6, 7]}}
}
scores = []
models = ["random_forest", "logistic_regression", "adaboost", "gradient_boosting", "xgboost", "decision_tree"]

for model_name in models:
    mp = model_params[model_name]
    gds = GridSearchCV(mp["model"], mp["params"], cv=5, return_train_score=True)
    gds.fit(x_train, y_train)
    scores.append({"model": model_name, "best_score": gds.best_score_, "best_params": gds.best_params_})
